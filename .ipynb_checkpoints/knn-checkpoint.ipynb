# %%
import pandas as pd
import numpy as np
import os 
import seaborn as sns
import matplotlib.pyplot as plt

# Import some of the packages/libraries you need for supervised learning
from scipy import stats
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics 

from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D


# %matplotlib inline 
os.listdir 

basedir = os.getcwd()
datadir = basedir + '/Data'

os.listdir(datadir)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

y_processed = pd.read_csv(datadir + '/y_processed.csv', index_col = 0)
X_processed = pd.read_csv(datadir  + '/X_processed.csv', index_col = 0)
y2_processed = pd.read_csv(datadir + '/y2_processed.csv', index_col = 0 )
X_processed.index.name = 'SampleID'

processedFD = pd.read_csv(datadir + '/processedFullData.csv', index_col = 0)
processedFD = processedFD.drop(['BarcodeSequence', 'LinkerPrimerSequence', 'BodySite', 'Race', 'Ethnicity', 
                                'Labor_Initiation', 'Indication','ReversePrimer', 'Saliva_volume_uL', 
                                'Note_any_concerns_regarding_the_specimen', 'Run_No', 'Gdwithdrawal', 'GWwithdrawal', 
                               'Bead_Beating_Time'], axis=1)

processedFD['History_of_preterm_delivery']= processedFD['History_of_preterm_delivery'].fillna(0, inplace = True)
processedFD['PPROM']=processedFD['PPROM'].fillna(0, inplace = True)
processedFD['Chorioamnionitis']=processedFD['Chorioamnionitis'].fillna(0, inplace = True)
processedFD['Endometritis']=processedFD['Endometritis'].fillna(0, inplace = True)
processedFD['Hypertensive Disorder']=processedFD['Hypertensive Disorder'].fillna(0, inplace = True)
processedFD['Preeclampsia']=processedFD['Preeclampsia'].fillna(0, inplace = True)
processedFD['Number_of_babies']=processedFD['Number_of_babies'].fillna(0, inplace = True)

def replaceFIUFD(row):
    if row['intra_ut_fetal_demise'] == 'F':
        return 0
    else: return 1

processedFD['intra_ut_fetal_demise'] = processedFD.apply(replaceFIUFD, axis = 1)

def replaceFW(row):
    if row['Withdrew'] == 'F':
        return 0
    else: return 1

processedFD['Withdrew'] = processedFD.apply(replaceFW, axis = 1)

def replaceFD(row):
    if row['Delivered'] == 'F':
        return 0
    else: return 1

processedFD['Delivered'] = processedFD.apply(replaceFD, axis = 1)
processedFD

# %%
y2_processed['ispreterm'].fillna(0, inplace= True)
# Define the inputs/features for the models you'll test below
x = X_processed

# Define the targets - what we are trying to predict or classify
# Here we are trying to predict the "rating_levels"
y = y2_processed['ispreterm']

# We'll save 20 percent of our data for testing and use 80 percent for training
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

from sklearn.neighbors import KNeighborsClassifier


k_range = range(1,4)
scores = {}
scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train.values.ravel())
    y_pred_knn = knn.predict(x_test)
    scores[k] = metrics.accuracy_score(y_test,y_pred_knn)
    scores_list.append(metrics.accuracy_score(y_test,y_pred_knn))
    
    fig = plt.figure(1, figsize=(8, 6))
    #ax = Axes3D(fig, elev=-150, azim=110)
    X_reduced = PCA(n_components=2).fit_transform(x_test)
    plt.scatter(X_reduced[:, 0], X_reduced[:, 1], edgecolor='k', s=40, c = y_pred_knn)
    
print('Accuracy:',scores_list)
# Out:
# Accuracy: [0.8368355995055624, 0.8949320148331273, 0.8665018541409147]

# %%
OTU_cols = X_processed.columns[X_processed.columns.str.startswith("OTU")]
X_processed['Unique_OTU'] = (X_processed[OTU_cols] > 0).sum(axis = 1)

#def average_OTU(row):
#    return mean_OTU[row['SampleID']]
                        
#X_processed['Mean_OTU'] = X_processed.apply(average_OTU,axis=1)

# %%
trimester = processedFD.groupby('TrimColl')
trimester['TrimColl'].value_counts()

trim1 = trimester.get_group(1)

# Define the inputs/features for the models you'll test below
x = trim1

# Define the targets - what we are trying to predict or classify
# Here we are trying to predict the "rating_levels"
y = trim1['Preterm']

# We'll save 20 percent of our data for testing and use 80 percent for training
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

from sklearn.neighbors import KNeighborsClassifier


k_range = range(1,4)
scores = {}
scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train.values.ravel())
    y_pred_knn = knn.predict(x_test)
    scores[k] = metrics.accuracy_score(y_test,y_pred_knn)
    scores_list.append(metrics.accuracy_score(y_test,y_pred_knn))
    
    fig = plt.figure(1, figsize=(8, 6))
    X_reduced = PCA(n_components=2).fit_transform(x_test)
    plt.scatter(X_reduced[:, 0], X_reduced[:, 1], edgecolor='k', s=40, c = y_pred_knn)

print('Accuracy:',scores_list)

# %%
trim1
# Out:
#                History_of_preterm_delivery  GestDayColl  GestWeekColl  \
# SampleID
# 1000701088                             0.0         71.0          10.0
# 1000701098                             0.0         81.0          12.0
# 1000101128                             0.0          4.0           1.0
# 1000704088                             0.0         71.0          10.0
# 1000704098                             0.0         81.0          12.0
# ...                                    ...          ...           ...
# 1003403088.rs                          1.0         57.0           9.0
# 1004603098.rs                          0.0         64.0          10.0
# 1004703138.rs                          0.0         91.0          13.0
# 1003904118.rs                          0.0         80.0          12.0
# 1004704138.rs                          0.0         91.0          13.0
#
#                TrimColl  BodySite_Cord Blood (Serum)  BodySite_Saliva  \
# SampleID
# 1000701088          1.0                            0                0
# 1000701098          1.0                            0                0
# 1000101128          1.0                            0                0
# 1000704088          1.0                            0                0
# 1000704098          1.0                            0                0
# ...                 ...                          ...              ...
# 1003403088.rs       1.0                            0                1
# 1004603098.rs       1.0                            0                1
# 1004703138.rs       1.0                            0                1
# 1003904118.rs       1.0                            0                0
# 1004704138.rs       1.0                            0                0
#
#                BodySite_Skin  BodySite_Stool  BodySite_Tooth_Gum  \
# SampleID
# 1000701088                 0               0                   0
# 1000701098                 0               0                   0
# 1000101128                 0               0                   0
# 1000704088                 0               0                   1
# 1000704098                 0               0                   1
# ...                      ...             ...                 ...
# 1003403088.rs              0               0                   0
# 1004603098.rs              0               0                   0
# 1004703138.rs              0               0                   0
# 1003904118.rs              0               0                   1
# 1004704138.rs              0               0                   1
#
#                BodySite_Urine  ...  coOTU_1452_1452  Shannon_entropy  \
# SampleID                       ...
# 1000701088                  0  ...                0         2.372042
# 1000701098                  0  ...                0         2.245429
# 1000101128                  0  ...                0         2.594979
# 1000704088                  0  ...              122         4.294271
# 1000704098                  0  ...              188         3.649151
# ...                       ...  ...              ...              ...
# 1003403088.rs               0  ...               16         4.923930
# 1004603098.rs               0  ...               66         4.278269
# 1004703138.rs               0  ...               54         4.656366
# 1003904118.rs               0  ...               28         3.231914
# 1004704138.rs               0  ...                0         2.429495
#
#                gini_index  dominance  brillouin_d       chao1   simpson  \
# SampleID
# 1000701088       0.997384   0.291113     1.615519   23.000000  0.708887
# 1000701098       0.997528   0.258394     1.534110   15.000000  0.741606
# 1000101128       0.996448   0.318741     1.741127   65.000000  0.681259
# 1000704088       0.988371   0.130768     2.837272  116.352941  0.869232
# 1000704098       0.989646   0.276944     2.434049  123.555556  0.723056
# ...                   ...        ...          ...         ...       ...
# 1003403088.rs    0.985393   0.069251     3.366212  190.913043  0.930749
# 1004603098.rs    0.990038   0.106763     2.908757  146.391304  0.893237
# 1004703138.rs    0.987278   0.086871     3.144975  153.272727  0.913129
# 1003904118.rs    0.991943   0.301347     2.202765  161.000000  0.698653
# 1004704138.rs    0.997036   0.269841     1.309673    8.600000  0.730159
#
#                singles  doubles  Unique_OTU
# SampleID
# 1000701088           5        1          19
# 1000701098           3        2          15
# 1000101128          21        9          45
# 1000704088          31       16          90
# 1000704098          29       17         102
# ...                ...      ...         ...
# 1003403088.rs       40       22         158
# 1004603098.rs       36       22         120
# 1004703138.rs       37       21         124
# 1003904118.rs       32       15         131
# 1004704138.rs        3        4           9
#
# [354 rows x 1967 columns]
